# %%
import pandas as pd
import numpy as np

# %% [markdown]
# # EDA

# %%
results_df = pd.read_csv('data/Formula1/results.csv')

# %%
results_df.head()
# Out:
#    resultId  raceId  driverId  constructorId number  grid position
# 0         1      18         1              1     22     1        1  \
# 1         2      18         2              2      3     5        2
# 2         3      18         3              3      7     7        3
# 3         4      18         4              4      5    11        4
# 4         5      18         5              1     23     3        5
#
#   positionText  positionOrder  points  laps         time milliseconds
# 0            1              1    10.0    58  1:34:50.616      5690616  \
# 1            2              2     8.0    58       +5.478      5696094
# 2            3              3     6.0    58       +8.163      5698779
# 3            4              4     5.0    58      +17.181      5707797
# 4            5              5     4.0    58      +18.014      5708630
#
#   fastestLap rank fastestLapTime fastestLapSpeed  statusId
# 0         39    2       1:27.452         218.300         1
# ...

# %%
races_df = pd.read_csv('data/Formula1/races.csv')
races_df.head()
# Out:
#    raceId  year  round  circuitId                   name        date
# 0       1  2009      1          1  Australian Grand Prix  2009-03-29  \
# 1       2  2009      2          2   Malaysian Grand Prix  2009-04-05
# 2       3  2009      3         17     Chinese Grand Prix  2009-04-19
# 3       4  2009      4          3     Bahrain Grand Prix  2009-04-26
# 4       5  2009      5          4     Spanish Grand Prix  2009-05-10
#
#        time                                                url fp1_date
# 0  06:00:00  http://en.wikipedia.org/wiki/2009_Australian_G...       \N  \
# 1  09:00:00  http://en.wikipedia.org/wiki/2009_Malaysian_Gr...       \N
# 2  07:00:00  http://en.wikipedia.org/wiki/2009_Chinese_Gran...       \N
# 3  12:00:00  http://en.wikipedia.org/wiki/2009_Bahrain_Gran...       \N
# 4  12:00:00  http://en.wikipedia.org/wiki/2009_Spanish_Gran...       \N
#
#   fp1_time fp2_date fp2_time fp3_date fp3_time quali_date quali_time
# ...

# %%
twentieth = races_df[(races_df['year']>=1990) & (races_df['year'] <2023)]

races_by_year = twentieth.groupby('year')['raceId'].apply(list).reset_index()

races_by_year['num_races'] = races_by_year['raceId'].str.len()

races_by_year
# Out:
#     year                                             raceId  num_races
# 0   1990  [321, 322, 323, 324, 325, 326, 327, 328, 329, ...         16
# 1   1991  [305, 306, 307, 308, 309, 310, 311, 312, 313, ...         16
# 2   1992  [289, 290, 291, 292, 293, 294, 295, 296, 297, ...         16
# 3   1993  [273, 274, 275, 276, 277, 278, 279, 280, 281, ...         16
# 4   1994  [257, 258, 259, 260, 261, 262, 263, 264, 265, ...         16
# 5   1995  [240, 241, 242, 243, 244, 245, 246, 247, 248, ...         17
# 6   1996  [224, 225, 226, 227, 228, 229, 230, 231, 232, ...         16
# 7   1997  [207, 208, 209, 210, 211, 212, 213, 214, 215, ...         17
# 8   1998  [191, 192, 193, 194, 195, 196, 197, 198, 199, ...         16
# 9   1999  [175, 176, 177, 178, 179, 180, 181, 182, 183, ...         16
# 10  2000  [158, 159, 160, 161, 162, 163, 164, 165, 166, ...         17
# 11  2001  [141, 142, 143, 144, 145, 146, 147, 148, 149, ...         17
# ...

# %%
#get a list of all the races from 2000-2022
twentieth_races_IDs = races_by_year['raceId'].explode()
twentieth_races_IDs
# Out:
# 0      321
# 0      322
# 0      323
# 0      324
# 0      325
#       ...
# 32    1092
# 32    1093
# 32    1094
# 32    1095
# 32    1096
# Name: raceId, Length: 595, dtype: object

# %%
results_df = pd.read_csv('data/Formula1/results.csv')
results_df
# Out:
#        resultId  raceId  driverId  constructorId number  grid position
# 0             1      18         1              1     22     1        1  \
# 1             2      18         2              2      3     5        2
# 2             3      18         3              3      7     7        3
# 3             4      18         4              4      5    11        4
# 4             5      18         5              1     23     3        5
# ...         ...     ...       ...            ...    ...   ...      ...
# 25835     25841    1096       854            210     47    12       16
# 25836     25842    1096       825            210     20    16       17
# 25837     25843    1096         1            131     44     5       18
# 25838     25844    1096       849              3      6    20       19
# 25839     25845    1096         4            214     14    10       \N
#
#       positionText  positionOrder  points  laps         time milliseconds
# ...

# %%
constructor_df = pd.read_csv('data/Formula1/constructor_standings.csv')
constructor_df
# Out:
#        constructorStandingsId  raceId  constructorId  points  position
# 0                           1      18              1    14.0         1  \
# 1                           2      18              2     8.0         3
# 2                           3      18              3     9.0         2
# 3                           4      18              4     5.0         4
# 4                           5      18              5     2.0         5
# ...                       ...     ...            ...     ...       ...
# 12936                   28408    1098            210     0.0         6
# 12937                   28409    1098              1     0.0         7
# 12938                   28410    1098            131     0.0         8
# 12939                   28411    1098              9     0.0         9
# 12940                   28412    1098              3     0.0        10
#
#       positionText  wins
# 0                1     1
# 1                3     0
# 2                2     0
# ...

# %%
constructor_results = pd.read_csv('data/Formula1/constructor_results.csv')
constructor_results
# Out:
#        constructorResultsId  raceId  constructorId  points status
# 0                         1      18              1    14.0     \N
# 1                         2      18              2     8.0     \N
# 2                         3      18              3     9.0     \N
# 3                         4      18              4     5.0     \N
# 4                         5      18              5     2.0     \N
# ...                     ...     ...            ...     ...    ...
# 12165                 16665    1096            117     5.0     \N
# 12166                 16666    1096            213     0.0     \N
# 12167                 16667    1096             51     0.0     \N
# 12168                 16668    1096              3     0.0     \N
# 12169                 16669    1096            210     0.0     \N
#
# [12170 rows x 5 columns]
